# %%
import pandas as pd
WV = pd.read_csv("data/process/embed_sbert_neighbors_top100_ner_web_trf.csv")
WV
# Out:
#                  the  -0.04747376590967178  0.074179507791996  \
# 0                and             -0.065812           0.048193
# 1                for             -0.080950           0.048515
# 2               that             -0.018246          -0.005750
# 3                you             -0.113688           0.028624
# 4               with             -0.001228           0.069698
# ...              ...                   ...                ...
# 26499           redd             -0.086010          -0.033597
# 26500       redstone             -0.059916           0.037076
# 26501          redux             -0.045524          -0.021559
# 26502  replenishment             -0.094971           0.026853
# 26503          rhoda             -0.026314          -0.032484
#
#        -0.046912699937820435  0.042617809027433395  -0.003820193698629737  \
# 0                   0.030481              0.024876               0.007960
# ...
