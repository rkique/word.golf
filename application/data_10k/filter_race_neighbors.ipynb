# %%
import pandas as pd
WV = pd.read_csv("embed_w2v.csv")
len(list(WV['word']))
# Out:
# 10038

# %%
good_lines = []
with open('race_neighbors.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        words = line.strip().split(',')
        present_words = [word for word in words if word in WV['word'].values]
        if len(present_words[0]) > 8 or len(present)
            good_lines.append(line)

with open('good_lines.txt', 'w') as out_f:
    out_f.writelines(good_lines)
